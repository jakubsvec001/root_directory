# %%
import pandas as pd

# %%
import numpy as np
import unicode
# Out:
# -------------------------------------------------------------------
# ModuleNotFoundError               Traceback (most recent call last)
# <ipython-input-46-38f46fd7bb02> in <module>
#       1 import numpy as np
# ----> 2 import unicode
#
# ModuleNotFoundError: No module named 'unicode'

# %%
data = pd.read_csv('data/math/math_articles_10260', sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10217 entries, 0 to 10216
# Data columns (total 1 columns):
# 0    10216 non-null object
# dtypes: object(1)
# memory usage: 79.9+ KB

# %%
data.head()
# Out:
#                     0
# 0       Inverse curve
# 1               Hypot
# 2   Convergence tests
# 3       Dupin cyclide
# 4  Total differential

# %%
data['clean'] = data.loc[:,0].apply(lambda x: str(x).replace('_', ' '))

# %%
new = data.loc[:,0].map(lambda x: str(x).replace('_',' '))

# %%
new.to_csv('data/math/math_articles_10260', sep='\t', encoding='utf-8', index=False)
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-88-a651f5c28a49> in <module>
# ----> 1 new.to_csv('data/math/math_articles_10260', sep='\t', encoding='utf-8', index=False)
#
# NameError: name 'new' is not defined

# %%
data = pd.read_csv('data/math/math_articles_10260', sep='\t', header=None, encoding='utf-8')

# %%
def return_not_journal(x):
    if 'journal' not in str(x).lower():
        return str(x)

# %%
data.shape
# Out:
# (10363,)

# %%
lst = []
for i in data[0]:
    if 'school' not in str(i).lower():
        lst.append(str(i))
    else:
        continue

# %%
data = pd.read_csv('data/math/math_articles_9189', sep='\t', encoding='utf-8')

# %%
data.drop_duplicates(inplace=True)

# %%
data = data.iloc[:,0].tolist()

# %%
len(data)
# Out:
# 8965

# %%
lst = []
for i in data:
    if 'census' not in str(i).lower():
        lst.append(str(i))
    else:
        continue

# %%
len(lst)
# Out:
# 8958

# %%
data = lst

# %%
data = pd.DataFrame(data)

# %%
data.shape
# Out:
# (8958, 1)

# %%
data.to_csv('data/math/math_articles_8958', sep='\t', encoding='utf-8', index=False)

# %%
totes = 0
for i in data[0]:
    if 'book' in str(i).lower():
        totes += 1

# %%
totes
# Out:
# 27

# %%
for i in data[0]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
